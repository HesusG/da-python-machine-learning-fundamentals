# %% [markdown]
# # Machine Learning Fundamentals
# ### Hesus Garcia
# #### Lección 7 - Agrupamiento
# ### Comparativo entre técnicas de agrupamiento
# Primero se importan los paquetes

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import cluster, datasets, mixture, metrics
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Crear datasets de prueba

# %%
np.random.seed(0)
n_samples = 1500
X = 6 * [None]

# Circulos concentricos 
xtemp, _ = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)
X[0] = StandardScaler().fit_transform(xtemp)

# Lunas
xtemp, _ = datasets.make_moons(n_samples=n_samples, noise=.05)
X[1] = StandardScaler().fit_transform(xtemp)

# Blobs
xtemp, _ = datasets.make_blobs(n_samples=n_samples, random_state=8)
X[2] = StandardScaler().fit_transform(xtemp)

# Plano sin agrupaciones
xtemp = np.random.rand(n_samples, 2)
X[3] = StandardScaler().fit_transform(xtemp)

# Blobs con deformación anisotropica
xtemp, _= datasets.make_blobs(n_samples=n_samples, random_state=170)
xtemp = np.dot(xtemp, [[0.6, -0.6], [-0.4, 0.8]])
X[4] = StandardScaler().fit_transform(xtemp)

# Blobs con varias varianzas
xtemp, _ = datasets.make_blobs(n_samples=n_samples,
                               cluster_std=[1.0, 2.5, 0.5])
X[5] = StandardScaler().fit_transform(xtemp)

# number of clusters
classes = [2,2,3,3,3,3]

# %% [markdown]
# Dibujar los datasets de prueba

# %%
plt.figure(figsize=(27,9))
for i in range(6):
    ax = plt.subplot(2, 3, i+1)
    ax.scatter(X[i][:,0], X[i][:,1])

# %% [markdown]
# Kmeans

# %%
y = []
for c, x in zip(classes, X):
    model = cluster.KMeans(n_clusters = c)
    model.fit(x)
    if hasattr(model, 'labels_'):
        y.append(model.labels_.astype(np.int))
    else:
        y.append(model.predict(x))
        
fig = plt.figure(figsize = (27,9))
fig.suptitle('Kmeans', fontsize=48)
for i in range(6):
    ax = plt.subplot(2,3,i+1)
    ax.scatter(X[i][:,0], X[i][:,1], c=y[i])

# %% [markdown]
# Birch

# %%
y = []
for c, x in zip(classes, X):
  model = cluster.Birch(n_clusters=c)
  model.fit(x)
  if hasattr(model, 'labels_'):
    y.append(model.labels_.astype(np.int))
  else:
    y.append(model.predict(x))

fig = plt.figure(figsize=(27,9))
fig.suptitle('Birch', fontsize=48)
for i in range(6):
  ax = plt.subplot(2, 3, i+1)
  ax.scatter(X[i][:,0], X[i][:,1], c=y[i])

# %% [markdown]
# Spectral Clustering

# %%
y = []
for c, x in zip(classes, X):
  model = cluster.SpectralClustering(n_clusters=c, 
                                     affinity="nearest_neighbors")
  model.fit(x)
  if hasattr(model, 'labels_'):
    y.append(model.labels_.astype(np.int))
  else:
    y.append(model.predict(x))

fig = plt.figure(figsize=(27,9))
fig.suptitle('SpectralClustering', fontsize=48)
for i in range(6):
  ax = plt.subplot(2, 3, i+1)
  ax.scatter(X[i][:,0], X[i][:,1], c=y[i])
# Out:
# C:\Users\aldac\Anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# C:\Users\aldac\Anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# C:\Users\aldac\Anaconda3\lib\site-packages\sklearn\manifold\_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %% [markdown]
# Gaussian Mixtures

# %%
y = []
for c, x in zip(classes, X):
  model = mixture.GaussianMixture(n_components=c, covariance_type='full')
  model.fit(x)
  if hasattr(model, 'labels_'):
    y.append(model.labels_.astype(np.int))
  else:
    y.append(model.predict(x))

fig = plt.figure(figsize=(27,9))
fig.suptitle('GaussianMixture', fontsize=48)
for i in range(6):
  ax = plt.subplot(2, 3, i+1)
  ax.scatter(X[i][:,0], X[i][:,1], c=y[i])

# %% [markdown]
# Optics

# %%
y = []
for c, x in zip(classes, X):
  model = cluster.OPTICS(min_samples=20, xi=0.05, min_cluster_size=0.1)
  model.fit(x)
  if hasattr(model, 'labels_'):
    y.append(model.labels_.astype(np.int))
  else:
    y.append(model.predict(x))

fig = plt.figure(figsize=(27,9))
fig.suptitle('OPTICS', fontsize=48)
for i in range(6):
  ax = plt.subplot(2, 3, i+1)
  ax.scatter(X[i][:,0], X[i][:,1], c=y[i])

# %% [markdown]
# DBSCAN

# %%
y = []
eps = [0.3, 0.3, 0.3, 0.3, 0.15, 0.18]
for c, x, e in zip(classes, X, eps):
  model = cluster.DBSCAN(eps=e)
  model.fit(x)
  if hasattr(model, 'labels_'):
    y.append(model.labels_.astype(np.int))
  else:
    y.append(model.predict(x))

fig = plt.figure(figsize=(27,9))
fig.suptitle('DBSCAN', fontsize=48)
for i in range(6):
  ax = plt.subplot(2, 3, i+1)
  ax.scatter(X[i][:,0], X[i][:,1], c=y[i])

# %% [markdown]
# ## Cuatnización de imagenes con Kmeans
# Importar paquetes

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from sklearn.cluster import KMeans
from sklearn.utils import shuffle

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
img = mpimg.imread('stormtrooper.jpg')
img = np.array(img, dtype=np.float64) / 255

# %%
w, h, d = img.shape
n_classes = 2

# %%
img_array = np.reshape(img, (w * h, d))

# %%
X = shuffle(img_array, random_state=0)[:1000]
kmeans = KMeans(n_clusters = n_classes, random_state = 0)
kmeans.fit(X)
labels = kmeans.predict(img_array)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1],  X[:,2],c=X)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1],X[:,2],c=kmeans.predict(X))

# %%
img_labels = np.reshape(labels, (w,h))
img_out = np.zeros((w, h, d))
label_idx = 0
for i in range(w):
  for j in range(h):
    img_out[i][j][0] = kmeans.cluster_centers_[img_labels[i][j]][0]
    img_out[i][j][1] = kmeans.cluster_centers_[img_labels[i][j]][1]
    img_out[i][j][2] = kmeans.cluster_centers_[img_labels[i][j]][2]

# %%
# Display all results, alongside original image
plt.title('Original image')
plt.imshow(img)

# %%
plt.title('Quantized image with K-Means')
plt.imshow(img_out)

# %% [markdown]
# ## Medidad de desempeño

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

def calculate_silhouette(data, n_clusters):
  plt.figure
  plt.xlim([-0.1, 1])
  clusterer = KMeans(n_clusters=n_clusters)
  cluster_labels = clusterer.fit_predict(data)

  silhouette_avg = silhouette_score(data, cluster_labels)
  print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

  sample_silhouette_values = silhouette_samples(data, cluster_labels)

  y_lower = 10
  for i in range(n_clusters):
    # Aggregate the silhouette scores for samples belonging to
    # cluster i, and sort them
    ith_cluster_silhouette_values = \
    sample_silhouette_values[cluster_labels == i]

    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = plt.cm.nipy_spectral(float(i) / n_clusters)
    plt.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)

    # Label the silhouette plots with their cluster numbers at the middle
    plt.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

    plt.title("The silhouette plot for the various clusters.")
    plt.xlabel("The silhouette coefficient values")
    plt.ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    plt.axvline(x=silhouette_avg, color="red", linestyle="--")

    plt.yticks([])  # Clear the yaxis labels / ticks
    plt.xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.show()

# %%
calculate_silhouette(X, 2)
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.6791865177569828

# %% [markdown]
# # Agrupamiento - Hacer una segmentacion de mercado usando tecnicas de agrupamiento

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/Dr-Carlos-Villasenor/ReconocimientoPatrones/master/Datasets/Mall_Customers.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df['new_gender'] = df['Gender'].map({'Male':0, 'Female':1})

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    new_gender
# 0           0
# 1           0
# 2           1
# 3           1
# 4           1

# %%
x_old = X

# %%
X = df[['new_gender','Age', 'Annual Income (k$)', 'Spending Score (1-100)']].values

# %%
X = StandardScaler().fit_transform(X)

# %%
## Dibujar
plt.figure(figsize=(27,15))


    
ax = plt.subplot(3, 2, 1)
ax.scatter(X[:,1], X[:,2], c = X[:,0], s=80)
ax.set_title('Age and anual income by gender', fontsize = 25)
ax.set_xlabel('Age', fontsize = 25)
ax.set_ylabel('Anual income', fontsize = 25)

ax = plt.subplot(3, 2, 2)
ax.scatter(X[:,1], X[:,3], c = X[:,0], s=80)
ax.set_title('Age and spending score by gender', fontsize = 25)
ax.set_xlabel('Age', fontsize = 25)
ax.set_ylabel('Spending score', fontsize = 25)


ax = plt.subplot(3, 2, 3)
ax.scatter(X[:,2], X[:,3], c = X[:,0], s=80)
ax.set_title('Anual income and spending score by gender', fontsize = 25)
ax.set_xlabel('Anual income', fontsize = 25)
ax.set_ylabel('Spending score', fontsize = 25)

ax = plt.subplot(3, 2, 4)
ax.scatter(X[:,2], X[:,3], c = X[:,1], s=80)
ax.set_title('Anual income and spending score by age', fontsize = 25)
ax.set_xlabel('Anual income', fontsize = 25)
ax.set_ylabel('Spending score', fontsize = 25)

ax = plt.subplot(3, 2, 5)
ax.scatter(X[:,0], X[:,1], c = X[:,0], s=80)
ax.set_title('Gender and age by gender', fontsize = 25)
ax.set_xlabel('Gender', fontsize = 25)
ax.set_ylabel('Age', fontsize = 25)
# Out:
# Text(0, 0.5, 'Age')

# %%
y = []
c = 5
#model = cluster.KMeans(n_clusters = c)
#model = cluster.SpectralClustering(n_clusters=c, affinity="nearest_neighbors")
model = cluster.OPTICS(min_samples=20, xi=0.05, min_cluster_size=0.1)
model.fit(X)

if hasattr(model, 'labels_'):
    y.append(model.labels_.astype(np.int))
else:
    y.append(model.predict(X))

# %%
## Dibujar
plt.figure(figsize=(27,15))


    
ax = plt.subplot(3, 2, 1)
ax.scatter(X[:,1], X[:,2], c = y[0], s = 80)
ax.set_title('Age and anual income by gender', fontsize = 25)
ax.set_xlabel('Age', fontsize = 25)
ax.set_ylabel('Anual income', fontsize = 25)

ax = plt.subplot(3, 2, 2)
ax.scatter(X[:,1], X[:,3], c = y[0], s = 80)
ax.set_title('Age and spending score by gender', fontsize = 25)
ax.set_xlabel('Age', fontsize = 25)
ax.set_ylabel('Spending score', fontsize = 25)


ax = plt.subplot(3, 2, 3)
ax.scatter(X[:,2], X[:,3], c = y[0], s = 80)
ax.set_title('Anual income and spending score by gender', fontsize = 25)
ax.set_xlabel('Anual income', fontsize = 25)
ax.set_ylabel('Spending score', fontsize = 25)

ax = plt.subplot(3, 2, 4)
ax.scatter(X[:,2], X[:,3], c = y[0], s = 80)
ax.set_title('Anual income and spending score by age', fontsize = 25)
ax.set_xlabel('Anual income', fontsize = 25)
ax.set_ylabel('Spending score', fontsize = 25)

ax = plt.subplot(3, 2, 5)
ax.scatter(X[:,0], X[:,1], c = y[0], s = 80)
ax.set_title('Gender and age by gender', fontsize = 25)
ax.set_xlabel('Gender', fontsize = 25)
ax.set_ylabel('Age', fontsize = 25)
# Out:
# Text(0, 0.5, 'Age')

# %%
calculate_silhouette(X, 6)
# Out:
# For n_clusters = 6 The average silhouette_score is : 0.3298100522422392

# %%
from sklearn.metrics import silhouette_samples, silhouette_score

def calculate_silhouette(data, n_clusters):
  plt.figure
  plt.xlim([-0.1, 1])
  clusterer = KMeans(n_clusters=n_clusters)
  #clusterer = cluster.Birch(n_clusters=c)
  #clusterer = cluster.SpectralClustering(n_clusters=c, affinity="nearest_neighbors")
  #clusterer = mixture.GaussianMixture(n_components=c, covariance_type='full')
  #clusterer = cluster.OPTICS(min_samples=20, xi=0.01, min_cluster_size=0.1)
  cluster_labels = clusterer.fit_predict(data)

  silhouette_avg = silhouette_score(data, cluster_labels)
  print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

  sample_silhouette_values = silhouette_samples(data, cluster_labels)

  y_lower = 10
  for i in range(n_clusters):
    # Aggregate the silhouette scores for samples belonging to
    # cluster i, and sort them
    ith_cluster_silhouette_values = \
    sample_silhouette_values[cluster_labels == i]

    ith_cluster_silhouette_values.sort()

    size_cluster_i = ith_cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = plt.cm.nipy_spectral(float(i) / n_clusters)
    plt.fill_betweenx(np.arange(y_lower, y_upper),
                      0, ith_cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)

    # Label the silhouette plots with their cluster numbers at the middle
    plt.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

    plt.title("The silhouette plot for the various clusters.")
    plt.xlabel("The silhouette coefficient values")
    plt.ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    plt.axvline(x=silhouette_avg, color="red", linestyle="--")

    plt.yticks([])  # Clear the yaxis labels / ticks
    plt.xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
  plt.show()
